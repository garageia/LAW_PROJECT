# %%
#Importing the library
import matplotlib.pyplot as plt
import keras_ocr
import glob
import os

pipeline = keras_ocr.pipeline.Pipeline()


# Chemin d'accès au répertoire contenant les fichiers d'images
directory = 'C:/Users/lenovo/Desktop/dat'

# Récupérer tous les fichiers d'images du répertoire
image_files = glob.glob(os.path.join(directory, '*.jpg')) + glob.glob(os.path.join(directory, '*.png'))

# Charger les images
images = [keras_ocr.tools.read(file) for file in image_files]

# Each list of predictions in prediction_groups is a list of
# (word, box) tuples.
prediction_groups = pipeline.recognize(images)

# Plot the predictions
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)
# Out:
# Looking for C:\Users\lenovo\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\lenovo\.keras-ocr\crnn_kurapan.h5
# 1/1 [==============================] - 85s 85s/step
# 14/14 [==============================] - 79s 5s/step

# %%
import csv
import matplotlib.pyplot as plt
import keras_ocr
import glob
import os

pipeline = keras_ocr.pipeline.Pipeline()

# Chemin d'accès au répertoire contenant les fichiers d'images
directory = 'C:/Users/lenovo/Desktop/dat'

# Récupérer tous les fichiers d'images du répertoire
image_files = glob.glob(os.path.join(directory, '*.jpg')) + glob.glob(os.path.join(directory, '*.png'))

# Charger les images
images = [keras_ocr.tools.read(file) for file in image_files]

# Each list of predictions in prediction_groups is a list of (word, box) tuples.
prediction_groups = pipeline.recognize(images)

# Créer un fichier CSV pour enregistrer le contenu extrait
csv_file = 'test.csv'

# Ouvrir le fichier CSV en mode écriture
with open(csv_file, 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Parcourir les prédictions pour chaque image
    for predictions in prediction_groups:
        # Extraire le texte de chaque prédiction
        texte_image = ' '.join([word for word, _ in predictions])
        
        # Vérifier si le texte extrait est vide
        if texte_image.strip():
            # Écrire le texte dans une nouvelle ligne du fichier CSV
            writer.writerow([texte_image])
# Out:
# Looking for C:\Users\lenovo\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\lenovo\.keras-ocr\crnn_kurapan.h5
# 1/1 [==============================] - 94s 94s/step
# 14/14 [==============================] - 104s 7s/step

# %%
import pandas as pd

# Chemin d'accès au fichier CSV
csv_file = 'test.csv'

# Charger le fichier CSV dans un DataFrame
df = pd.read_csv(csv_file)

# Afficher toutes les lignes du DataFrame sans troncature
pd.set_option('display.max_rows', None)
print(df)
# Out:
#   systemes information d deployer yvelines sud ght dpi le le va hopital de medical manager softway fdmp fdonnees fsih qo s 18 2410212020 versailles hospitalier de etablissement ticsante le ch versailles centre du hospitalier de sud territoire ght yvelines lance support groupement a un de dossier alechelle de informatise dpi du projet mise patient en ceuvre de lediteur choisi hopital eo sofwaymedical atil manager groupement et a g annonce le fevrier dans communique 11 un d alechelle du choisie lensemble des ght seule solution ete et une meme a pour 5 dactivite de charge le optimiser les patients dpi et prise secteurs en pour parcours 5
# 0  systemes dinformation deployer ght sud dpi le ...
